# %% [markdown]
# # **Brain Tumor Image Classifier**

# %% [markdown]
# ## **Context**
#
# In this notebook, we will build an image classifier that can distinguish Pituitary Tumor from "No Tumor" MRI Scan images.
#
# The dataset used in this notebook is available for download from [Kaggle](https://www.kaggle.com/datasets/sartajbhuvaji/brain-tumor-classification-mri).
#
# Although this dataset actually has a total of 3,264 images belonging to 4 classes - Glioma Tumor, Meningioma Tumor, Pituitary Tumor and No Tumor, for this project we have only taken two classes, and **we are building a binary classification model to classify between the Pituitary Tumor category vs No Tumor.**
#
# For this project, we will only use 1000 of these images (830 training images and 170 Testing images). For the training dataset, we will take 395 MRI scans of No Tumor and 435 MRI scans of Pituitary Tumor. In our problem, we will also be using Data Augmentation to prevent overfitting, and to make our model model more generalised and robust.
#
# We will use this to build an image classification model for this problem statement, and then show how we can improve our performance by simply "importing" a popular pre-trained model architecture and leveraging the idea of **Transfer Learning**.
#
# ## **Objectives**
# The objectives of this project are to:
# 1. Load and understand the dataset
# 2. Automatically label the images
# 3. Perform Data Augmentation
# 4. Build a classification model for this problem using CNNs
# 5. Improve the model's performance through Transfer Learning

# %% [markdown]
# ## **Importing Libraries**

# %%
# Library for creating data paths
import os

# Library for randomly selecting data points
import random

# Library for performing numerical computations
import numpy as np

# Library for creating and showing plots
import matplotlib.pyplot as plt

# Library for reading and showing images
import matplotlib.image as mpimg

import os
import numpy as np                                                                               # Importing numpy for Matrix Operations
import pandas as pd                                                                              # Importing pandas to read CSV files
import matplotlib.pyplot as plt                                                                  # Importting matplotlib for Plotting and visualizing images
import math                                                                                      # Importing math module to perform mathematical operations
import cv2                                                                                       # Importing openCV for image processing
import seaborn as sns                                                                            # Importing seaborn to plot graphs


# Tensorflow modules
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator                              # Importing the ImageDataGenerator for data augmentation
from tensorflow.keras.models import Sequential                                                   # Importing the sequential module to define a sequential model
from tensorflow.keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,BatchNormalization # Defining all the layers to build our CNN Model
from tensorflow.keras.optimizers import Adam,SGD                                                 # Importing the optimizers which can be used in our model
from sklearn import preprocessing                                                                # Importing the preprocessing module to preprocess the data
from sklearn.model_selection import train_test_split                                             # Importing train_test_split function to split the data into train and test
from sklearn.metrics import confusion_matrix                                                     # Importing confusion_matrix to plot the confusion matrix

# Display images using OpenCV
from google.colab.patches import cv2_imshow                                                      # Importing cv2_imshow from google.patches to display images

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

from tensorflow.keras.models import Model

from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import load_img,img_to_array

#from keras.preprocessing.image import  load_img
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout

# %% [markdown]
# Mounting the drive to load the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Austin Texas/Computer Vision/Computer Vision/Week2/brain_tumor-1.zip"
# Out:
# Archive:  /content/drive/MyDrive/Austin Texas/Computer Vision/Computer Vision/Week2/brain_tumor-1.zip
#   inflating: brain_tumor/.DS_Store
#   inflating: brain_tumor/Training/.DS_Store
#   inflating: brain_tumor/Testing/.DS_Store
#   inflating: brain_tumor/Training/no_tumor/image(87).jpg
#   inflating: brain_tumor/Training/no_tumor/image (52).jpg
#   inflating: brain_tumor/Training/no_tumor/image(157).jpg
#   inflating: brain_tumor/Training/no_tumor/image(243).jpg
#   inflating: brain_tumor/Training/no_tumor/image(230).jpg
#   inflating: brain_tumor/Training/no_tumor/image(218).jpg
#   inflating: brain_tumor/Training/no_tumor/image(264).jpg
#   inflating: brain_tumor/Training/no_tumor/image(7).jpg
#   inflating: brain_tumor/Training/no_tumor/image (20).jpg
#   inflating: brain_tumor/Training/no_tumor/image(100).jpg
#   inflating: brain_tumor/Training/no_tumor/image(198).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(31).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(8).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(42).jpg
#   inflating: brain_tumor/Training/no_tumor/image(41).jpg
#   inflating: brain_tumor/Training/no_tumor/image(208).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(35).jpg
#   inflating: brain_tumor/Training/no_tumor/image(234).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(15).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(19).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/.DS_Store
#   inflating: brain_tumor/Testing/pituitary_tumor/image(36).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(7).jpg
#   inflating: brain_tumor/Training/no_tumor/image(321).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(79).jpg
#   inflating: brain_tumor/Training/no_tumor/image(178).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(86).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(11).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(77).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(55).jpg
#   inflating: brain_tumor/Training/no_tumor/image (35).jpg
#   inflating: brain_tumor/Training/no_tumor/image(251).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(85).jpg
#   inflating: brain_tumor/Training/no_tumor/image(1).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(46).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(27).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(21).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(87).jpg
#   inflating: brain_tumor/Training/no_tumor/image(319).jpg
#   inflating: brain_tumor/Testing/no_tumor/.DS_Store
#   inflating: brain_tumor/Training/no_tumor/image(311).jpg
#   inflating: brain_tumor/Training/no_tumor/image(145).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(13).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(53).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(44).jpg
#   inflating: brain_tumor/Training/no_tumor/image(205).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(23).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(18).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(80).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(31).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(81).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(67).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(63).jpg
#   inflating: brain_tumor/Training/no_tumor/image (60).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(49).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(30).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(84).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(78).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(58).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(61).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (536).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (648).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(36).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (758).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (754).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (498).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/.DS_Store
#   inflating: brain_tumor/Training/pituitary_tumor/p (760).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(50).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(55).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (779).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (556).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(22).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (636).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (630).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(74).jpg
#   inflating: brain_tumor/Training/no_tumor/image (6).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(69).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (742).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(86).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (789).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (820).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (660).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(47).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (549).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (558).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (595).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (790).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(62).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(42).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(57).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (656).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (599).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(12).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (776).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(35).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (631).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (521).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (668).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(19).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(37).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(43).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(22).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(66).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(41).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(92).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(94).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(65).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(93).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(95).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(45).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(90).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(60).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(30).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (543).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (767).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(67).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(5).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(88).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (571).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(73).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (775).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (581).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (827).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (625).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (811).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (649).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (579).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (680).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (598).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (765).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (745).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (507).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(87).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(51).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(68).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (712).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(64).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (628).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(70).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(56).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (780).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(44).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(98).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(20).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(27).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (618).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (644).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(101).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(15).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(49).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (512).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(11).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(46).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(102).jpg
#   inflating: brain_tumor/Training/no_tumor/image (31).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(59).jpg
#   inflating: brain_tumor/Training/no_tumor/image(33).jpg
#   inflating: brain_tumor/Training/no_tumor/image(61).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (819).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(54).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(26).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(48).jpg
#   inflating: brain_tumor/Training/no_tumor/1.jpg
#   inflating: brain_tumor/Testing/no_tumor/image(81).jpg
#   inflating: brain_tumor/Training/no_tumor/image(179).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(34).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(72).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (505).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(33).jpg
#   inflating: brain_tumor/Training/no_tumor/image(254).jpg
#   inflating: brain_tumor/Training/no_tumor/image(292).jpg
#   inflating: brain_tumor/Training/no_tumor/image(310).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (576).jpg
#   inflating: brain_tumor/Training/no_tumor/image(51).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (496).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(79).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(45).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(89).jpg
#   inflating: brain_tumor/Training/no_tumor/image(73).jpg
#   inflating: brain_tumor/Training/no_tumor/image(93).jpg
#   inflating: brain_tumor/Training/no_tumor/image(194).jpg
#   inflating: brain_tumor/Training/no_tumor/image(308).jpg
#   inflating: brain_tumor/Training/no_tumor/image(183).jpg
#   inflating: brain_tumor/Training/no_tumor/image(132).jpg
#   inflating: brain_tumor/Training/no_tumor/image(204).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(71).jpg
#   inflating: brain_tumor/Training/no_tumor/image(318).jpg
#   inflating: brain_tumor/Training/no_tumor/image (25).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(18).jpg
#   inflating: brain_tumor/Training/no_tumor/image(84).jpg
#   inflating: brain_tumor/Training/no_tumor/image (42).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(82).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(56).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(63).jpg
#   inflating: brain_tumor/Training/no_tumor/image(91).jpg
#   inflating: brain_tumor/Training/no_tumor/image(16).jpg
#   inflating: brain_tumor/Training/no_tumor/image(101).jpg
#   inflating: brain_tumor/Training/no_tumor/image(227).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (553).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (770).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (822).jpg
#   inflating: brain_tumor/Training/no_tumor/image(70).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (809).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (613).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (647).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (785).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (662).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (523).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (577).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (658).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(53).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (783).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(9).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (538).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (823).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (494).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (654).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(76).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (735).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (666).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(23).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (503).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(29).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(13).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(17).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(6).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (537).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (560).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(16).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(38).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(32).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(83).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(99).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(93).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(60).jpg
#   inflating: brain_tumor/Training/no_tumor/image(257).jpg
#   inflating: brain_tumor/Training/no_tumor/image (39).jpg
#   inflating: brain_tumor/Training/no_tumor/image(50).jpg
#   inflating: brain_tumor/Training/no_tumor/image(245).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (708).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (711).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(28).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(41).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (808).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(5).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(25).jpg
#   inflating: brain_tumor/Training/no_tumor/image(64).jpg
#   inflating: brain_tumor/Training/no_tumor/image(62).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (726).jpg
#   inflating: brain_tumor/Training/no_tumor/image(197).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(103).jpg
#   inflating: brain_tumor/Training/no_tumor/image (53).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(89).jpg
#   inflating: brain_tumor/Training/no_tumor/image(233).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(10).jpg
#   inflating: brain_tumor/Training/no_tumor/image(127).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(47).jpg
#   inflating: brain_tumor/Training/no_tumor/image(115).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(48).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(51).jpg
#   inflating: brain_tumor/Training/no_tumor/image(247).jpg
#   inflating: brain_tumor/Training/no_tumor/image(260).jpg
#   inflating: brain_tumor/Training/no_tumor/image (51).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(96).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(38).jpg
#   inflating: brain_tumor/Training/no_tumor/image(63).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(14).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(78).jpg
#   inflating: brain_tumor/Training/no_tumor/image(29).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(54).jpg
#   inflating: brain_tumor/Training/no_tumor/image(221).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(34).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(98).jpg
#   inflating: brain_tumor/Training/no_tumor/image(6).jpg
#   inflating: brain_tumor/Training/no_tumor/image(281).jpg
#   inflating: brain_tumor/Training/no_tumor/image (50).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(97).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(61).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(20).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(95).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(91).jpg
#   inflating: brain_tumor/Training/no_tumor/image(30).jpg
#   inflating: brain_tumor/Training/no_tumor/image (62).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(96).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(10).jpg
#   inflating: brain_tumor/Training/no_tumor/image (23).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(76).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(52).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(82).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(6).jpg
#   inflating: brain_tumor/Training/no_tumor/image(38).jpg
#   inflating: brain_tumor/Training/no_tumor/image(314).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(69).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(28).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (729).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (703).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (608).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (784).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (778).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (782).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (793).jpg
#   inflating: brain_tumor/Testing/pituitary_tumor/image(57).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(75).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (747).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (539).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (531).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(88).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (622).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (721).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(8).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (548).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(24).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (557).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(90).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (777).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (755).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(70).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (799).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(40).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(68).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (634).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (791).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(85).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(64).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(73).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(21).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (607).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (771).jpg
#   inflating: brain_tumor/Training/no_tumor/2.jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (554).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (619).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(77).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(66).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(104).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(39).jpg
#   inflating: brain_tumor/Training/no_tumor/image(66).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (585).jpg
#   inflating: brain_tumor/Training/no_tumor/image(128).jpg
#   inflating: brain_tumor/Training/no_tumor/image(114).jpg
#   inflating: brain_tumor/Training/no_tumor/image(240).jpg
#   inflating: brain_tumor/Training/no_tumor/image(255).jpg
#   inflating: brain_tumor/Training/no_tumor/image (5).jpg
#   inflating: brain_tumor/Training/no_tumor/image (64).jpg
#   inflating: brain_tumor/Training/no_tumor/image(253).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (751).jpg
#   inflating: brain_tumor/Training/no_tumor/image(280).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(97).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(37).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(52).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(94).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(43).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(7).jpg
#   inflating: brain_tumor/Training/no_tumor/image(168).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(65).jpg
#   inflating: brain_tumor/Training/no_tumor/image(206).jpg
#   inflating: brain_tumor/Training/no_tumor/image (28).jpg
#   inflating: brain_tumor/Training/no_tumor/image(58).jpg
#   inflating: brain_tumor/Training/no_tumor/image(77).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(100).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(92).jpg
#   inflating: brain_tumor/Testing/no_tumor/image(91).jpg
#   inflating: brain_tumor/Training/no_tumor/image(313).jpg
#   inflating: brain_tumor/Training/no_tumor/image(105).jpg
#   inflating: brain_tumor/Training/no_tumor/image(32).jpg
#   inflating: brain_tumor/Training/no_tumor/image(135).jpg
#   inflating: brain_tumor/Training/no_tumor/image(31).jpg
#   inflating: brain_tumor/Training/no_tumor/image(75).jpg
#   inflating: brain_tumor/Training/no_tumor/image(175).jpg
#   inflating: brain_tumor/Training/no_tumor/image(184).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (719).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (756).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (671).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (661).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (803).jpg
#   inflating: brain_tumor/Training/no_tumor/image (41).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (573).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (580).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (604).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (610).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (509).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (693).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (546).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (527).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (605).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (664).jpg
#   inflating: brain_tumor/Training/no_tumor/image(316).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (567).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (817).jpg
#   inflating: brain_tumor/Training/no_tumor/image(24).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (724).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (609).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (518).jpg
#   inflating: brain_tumor/Training/no_tumor/image(228).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (692).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (788).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (500).jpg
#   inflating: brain_tumor/Training/no_tumor/image(282).jpg
#   inflating: brain_tumor/Training/no_tumor/image(88).jpg
#   inflating: brain_tumor/Training/no_tumor/image(209).jpg
#   inflating: brain_tumor/Training/no_tumor/image(170).jpg
#   inflating: brain_tumor/Training/no_tumor/image(173).jpg
#   inflating: brain_tumor/Training/no_tumor/image(235).jpg
#   inflating: brain_tumor/Training/no_tumor/image(174).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (626).jpg
#   inflating: brain_tumor/Training/no_tumor/image(149).jpg
#   inflating: brain_tumor/Training/no_tumor/image (30).jpg
#   inflating: brain_tumor/Training/no_tumor/image(34).jpg
#   inflating: brain_tumor/Training/no_tumor/image(108).jpg
#   inflating: brain_tumor/Training/no_tumor/image(37).jpg
#   inflating: brain_tumor/Training/no_tumor/image(27).jpg
#   inflating: brain_tumor/Training/no_tumor/image(317).jpg
#   inflating: brain_tumor/Training/no_tumor/image(222).jpg
#   inflating: brain_tumor/Training/no_tumor/image(46).jpg
#   inflating: brain_tumor/Training/no_tumor/image(284).jpg
#   inflating: brain_tumor/Training/no_tumor/image(216).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (816).jpg
#   inflating: brain_tumor/Training/no_tumor/image(133).jpg
#   inflating: brain_tumor/Training/no_tumor/image(103).jpg
#   inflating: brain_tumor/Training/no_tumor/image(169).jpg
#   inflating: brain_tumor/Training/no_tumor/image (43).jpg
#   inflating: brain_tumor/Training/no_tumor/image(190).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (532).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (566).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (621).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (606).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (723).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (802).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (717).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (650).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (826).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (510).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (740).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (574).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (796).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (810).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (563).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (600).jpg
#   inflating: brain_tumor/Training/no_tumor/image(322).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (691).jpg
#   inflating: brain_tumor/Training/no_tumor/image(327).jpg
#   inflating: brain_tumor/Training/no_tumor/image (22).jpg
#   inflating: brain_tumor/Training/no_tumor/image(65).jpg
#   inflating: brain_tumor/Training/no_tumor/image(185).jpg
#   inflating: brain_tumor/Training/no_tumor/image(195).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (749).jpg
#   inflating: brain_tumor/Training/no_tumor/image(22).jpg
#   inflating: brain_tumor/Training/no_tumor/image(136).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (677).jpg
#   inflating: brain_tumor/Training/no_tumor/image (15).jpg
#   inflating: brain_tumor/Training/no_tumor/image(252).jpg
#   inflating: brain_tumor/Training/no_tumor/image(276).jpg
#   inflating: brain_tumor/Training/no_tumor/4.jpg
#   inflating: brain_tumor/Training/no_tumor/image (9).jpg
#   inflating: brain_tumor/Training/no_tumor/image(125).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (805).jpg
#   inflating: brain_tumor/Training/no_tumor/image(202).jpg
#   inflating: brain_tumor/Training/no_tumor/image (58).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (528).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (589).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (552).jpg
#   inflating: brain_tumor/Training/no_tumor/image(232).jpg
#   inflating: brain_tumor/Training/no_tumor/image(278).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (530).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (583).jpg
#   inflating: brain_tumor/Training/no_tumor/image (38).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (603).jpg
#   inflating: brain_tumor/Training/no_tumor/image(74).jpg
#   inflating: brain_tumor/Training/no_tumor/image(25).jpg
#   inflating: brain_tumor/Training/no_tumor/image(215).jpg
#   inflating: brain_tumor/Training/no_tumor/image(72).jpg
#   inflating: brain_tumor/Training/no_tumor/image(148).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (641).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (813).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (578).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (561).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (800).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (513).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (565).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (508).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (694).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (741).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (807).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (620).jpg
#   inflating: brain_tumor/Training/no_tumor/image(15).jpg
#   inflating: brain_tumor/Training/no_tumor/image(69).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (516).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (774).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (514).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (768).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (824).jpg
#   inflating: brain_tumor/Training/no_tumor/image(71).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (643).jpg
#   inflating: brain_tumor/Training/no_tumor/image(53).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (705).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (797).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (584).jpg
#   inflating: brain_tumor/Training/no_tumor/image(160).jpg
#   inflating: brain_tumor/Training/no_tumor/image(76).jpg
#   inflating: brain_tumor/Training/no_tumor/image(142).jpg
#   inflating: brain_tumor/Training/no_tumor/image(59).jpg
#   inflating: brain_tumor/Training/no_tumor/5.jpg
#   inflating: brain_tumor/Training/no_tumor/image(249).jpg
#   inflating: brain_tumor/Training/no_tumor/image(274).jpg
#   inflating: brain_tumor/Training/no_tumor/image(296).jpg
#   inflating: brain_tumor/Training/no_tumor/image(5).jpg
#   inflating: brain_tumor/Training/no_tumor/image(2).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (594).jpg
#   inflating: brain_tumor/Training/no_tumor/image(154).jpg
#   inflating: brain_tumor/Training/no_tumor/image(290).jpg
#   inflating: brain_tumor/Training/no_tumor/image(166).jpg
#   inflating: brain_tumor/Training/no_tumor/image(271).jpg
#   inflating: brain_tumor/Training/no_tumor/image(163).jpg
#   inflating: brain_tumor/Training/no_tumor/image(152).jpg
#   inflating: brain_tumor/Training/no_tumor/image (24).jpg
#   inflating: brain_tumor/Training/no_tumor/image(241).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (714).jpg
#   inflating: brain_tumor/Training/no_tumor/image(129).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (615).jpg
#   inflating: brain_tumor/Training/no_tumor/image(45).jpg
#   inflating: brain_tumor/Training/no_tumor/image(211).jpg
#   inflating: brain_tumor/Training/no_tumor/image(295).jpg
#   inflating: brain_tumor/Training/no_tumor/image(117).jpg
#   inflating: brain_tumor/Training/no_tumor/image(144).jpg
#   inflating: brain_tumor/Training/no_tumor/image(283).jpg
#   inflating: brain_tumor/Training/no_tumor/image (19).jpg
#   inflating: brain_tumor/Training/no_tumor/image(94).jpg
#   inflating: brain_tumor/Training/no_tumor/image(242).jpg
#   inflating: brain_tumor/Training/no_tumor/image (37).jpg
#   inflating: brain_tumor/Training/no_tumor/image(294).jpg
#   inflating: brain_tumor/Training/no_tumor/image(187).jpg
#   inflating: brain_tumor/Training/no_tumor/image(207).jpg
#   inflating: brain_tumor/Training/no_tumor/image(146).jpg
#   inflating: brain_tumor/Training/no_tumor/image(272).jpg
#   inflating: brain_tumor/Training/no_tumor/image (8).jpg
#   inflating: brain_tumor/Training/no_tumor/image(217).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (715).jpg
#   inflating: brain_tumor/Training/no_tumor/image(9).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (533).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (657).jpg
#   inflating: brain_tumor/Training/no_tumor/image(68).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (674).jpg
#   inflating: brain_tumor/Training/no_tumor/image(57).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (551).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (568).jpg
#   inflating: brain_tumor/Training/no_tumor/image(147).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (587).jpg
#   inflating: brain_tumor/Training/no_tumor/image(320).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (757).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (575).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (550).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (623).jpg
#   inflating: brain_tumor/Training/no_tumor/image(52).jpg
#   inflating: brain_tumor/Training/no_tumor/image(138).jpg
#   inflating: brain_tumor/Training/no_tumor/image(17).jpg
#   inflating: brain_tumor/Training/no_tumor/image(4).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (614).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (698).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (773).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (570).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (545).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (709).jpg
#   inflating: brain_tumor/Training/no_tumor/image(96).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (495).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (739).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (733).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (669).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (627).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (699).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (611).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (586).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (617).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (582).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (697).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (718).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (635).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (732).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (762).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (713).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (562).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (629).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (764).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (675).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (798).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (801).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (814).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (592).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (659).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (763).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (702).jpg
#   inflating: brain_tumor/Training/no_tumor/image(262).jpg
#   inflating: brain_tumor/Training/no_tumor/image(143).jpg
#   inflating: brain_tumor/Training/no_tumor/image(246).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (701).jpg
#   inflating: brain_tumor/Training/no_tumor/image(21).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (706).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (670).jpg
#   inflating: brain_tumor/Training/no_tumor/image(237).jpg
#   inflating: brain_tumor/Training/no_tumor/image(269).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (535).jpg
#   inflating: brain_tumor/Training/no_tumor/image(158).jpg
#   inflating: brain_tumor/Training/no_tumor/image.jpg
#   inflating: brain_tumor/Training/no_tumor/image(35).jpg
#   inflating: brain_tumor/Training/no_tumor/image(43).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (642).jpg
#   inflating: brain_tumor/Training/no_tumor/6.jpg
#   inflating: brain_tumor/Training/no_tumor/image(28).jpg
#   inflating: brain_tumor/Training/no_tumor/image(267).jpg
#   inflating: brain_tumor/Training/no_tumor/image (49).jpg
#   inflating: brain_tumor/Training/no_tumor/image(80).jpg
#   inflating: brain_tumor/Training/no_tumor/image(23).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (646).jpg
#   inflating: brain_tumor/Training/no_tumor/image(326).jpg
#   inflating: brain_tumor/Training/no_tumor/image (13).jpg
#   inflating: brain_tumor/Training/no_tumor/image(112).jpg
#   inflating: brain_tumor/Training/no_tumor/image(200).jpg
#   inflating: brain_tumor/Training/no_tumor/image (46).jpg
#   inflating: brain_tumor/Training/no_tumor/image(10).jpg
#   inflating: brain_tumor/Training/no_tumor/image(244).jpg
#   inflating: brain_tumor/Training/no_tumor/image(113).jpg
#   inflating: brain_tumor/Training/no_tumor/image(86).jpg
#   inflating: brain_tumor/Training/no_tumor/image(191).jpg
#   inflating: brain_tumor/Training/no_tumor/image(268).jpg
#   inflating: brain_tumor/Training/no_tumor/image(306).jpg
#   inflating: brain_tumor/Training/no_tumor/image(159).jpg
#   inflating: brain_tumor/Training/no_tumor/image(92).jpg
#   inflating: brain_tumor/Training/no_tumor/image (11).jpg
#   inflating: brain_tumor/Training/no_tumor/image(303).jpg
#   inflating: brain_tumor/Training/no_tumor/image(153).jpg
#   inflating: brain_tumor/Training/no_tumor/image(210).jpg
#   inflating: brain_tumor/Training/no_tumor/image(259).jpg
#   inflating: brain_tumor/Training/no_tumor/image(193).jpg
#   inflating: brain_tumor/Training/no_tumor/image(123).jpg
#   inflating: brain_tumor/Training/no_tumor/image(20).jpg
#   inflating: brain_tumor/Training/no_tumor/image(291).jpg
#   inflating: brain_tumor/Training/no_tumor/image(98).jpg
#   inflating: brain_tumor/Training/no_tumor/image (26).jpg
#   inflating: brain_tumor/Training/no_tumor/image(315).jpg
#   inflating: brain_tumor/Training/no_tumor/image(47).jpg
#   inflating: brain_tumor/Training/no_tumor/image(293).jpg
#   inflating: brain_tumor/Training/no_tumor/image(172).jpg
#   inflating: brain_tumor/Training/no_tumor/image (61).jpg
#   inflating: brain_tumor/Training/no_tumor/image(263).jpg
#   inflating: brain_tumor/Training/no_tumor/image(26).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (825).jpg
#   inflating: brain_tumor/Training/no_tumor/image(189).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (795).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (707).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (520).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (750).jpg
#   inflating: brain_tumor/Training/no_tumor/8.jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (663).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (730).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (722).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (515).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (672).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (695).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (645).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (686).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (519).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (624).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (525).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (821).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (596).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (781).jpg
#   inflating: brain_tumor/Training/no_tumor/image(156).jpg
#   inflating: brain_tumor/Training/no_tumor/image(40).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (769).jpg
#   inflating: brain_tumor/Training/no_tumor/image (21).jpg
#   inflating: brain_tumor/Training/no_tumor/image(325).jpg
#   inflating: brain_tumor/Training/no_tumor/image (16).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (572).jpg
#   inflating: brain_tumor/Training/no_tumor/image(122).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (690).jpg
#   inflating: brain_tumor/Training/no_tumor/image (18).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (792).jpg
#   inflating: brain_tumor/Training/no_tumor/image (44).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (794).jpg
#   inflating: brain_tumor/Training/no_tumor/image(199).jpg
#   inflating: brain_tumor/Training/no_tumor/image(258).jpg
#   inflating: brain_tumor/Training/no_tumor/image(151).jpg
#   inflating: brain_tumor/Training/no_tumor/image (40).jpg
#   inflating: brain_tumor/Training/no_tumor/image(203).jpg
#   inflating: brain_tumor/Training/no_tumor/image(248).jpg
#   inflating: brain_tumor/Training/no_tumor/image(167).jpg
#   inflating: brain_tumor/Training/no_tumor/image(287).jpg
#   inflating: brain_tumor/Training/no_tumor/image(220).jpg
#   inflating: brain_tumor/Training/no_tumor/image(301).jpg
#   inflating: brain_tumor/Training/no_tumor/image(256).jpg
#   inflating: brain_tumor/Training/no_tumor/image (10).jpg
#   inflating: brain_tumor/Training/no_tumor/image(192).jpg
#   inflating: brain_tumor/Training/no_tumor/image(223).jpg
#   inflating: brain_tumor/Training/no_tumor/image(226).jpg
#   inflating: brain_tumor/Training/no_tumor/image (36).jpg
#   inflating: brain_tumor/Training/no_tumor/image(213).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (682).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (759).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (684).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (517).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (591).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (640).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (683).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (815).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (541).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (653).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (710).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (655).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (704).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (529).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (736).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (632).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (679).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (804).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (685).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (696).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (597).jpg
#   inflating: brain_tumor/Training/no_tumor/image(266).jpg
#   inflating: brain_tumor/Training/no_tumor/image(3).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (590).jpg
#   inflating: brain_tumor/Training/no_tumor/image(42).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (588).jpg
#   inflating: brain_tumor/Training/no_tumor/image (56).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (601).jpg
#   inflating: brain_tumor/Training/no_tumor/image (54).jpg
#   inflating: brain_tumor/Training/no_tumor/image(116).jpg
#   inflating: brain_tumor/Training/no_tumor/image (17).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (806).jpg
#   inflating: brain_tumor/Training/no_tumor/image(131).jpg
#   inflating: brain_tumor/Training/no_tumor/image(312).jpg
#   inflating: brain_tumor/Training/no_tumor/image (14).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (534).jpg
#   inflating: brain_tumor/Training/no_tumor/image(60).jpg
#   inflating: brain_tumor/Training/no_tumor/image(18).jpg
#   inflating: brain_tumor/Training/no_tumor/image(79).jpg
#   inflating: brain_tumor/Training/no_tumor/image(176).jpg
#   inflating: brain_tumor/Training/no_tumor/image(119).jpg
#   inflating: brain_tumor/Training/no_tumor/image(48).jpg
#   inflating: brain_tumor/Training/no_tumor/3.jpg
#   inflating: brain_tumor/Training/no_tumor/image(188).jpg
#   inflating: brain_tumor/Training/no_tumor/image(201).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (665).jpg
#   inflating: brain_tumor/Training/no_tumor/image(214).jpg
#   inflating: brain_tumor/Training/no_tumor/image(165).jpg
#   inflating: brain_tumor/Training/no_tumor/image(224).jpg
#   inflating: brain_tumor/Training/no_tumor/image(67).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (676).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (737).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (511).jpg
#   inflating: brain_tumor/Training/no_tumor/image(299).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (678).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (639).jpg
#   inflating: brain_tumor/Training/no_tumor/image(137).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (818).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (499).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (593).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (753).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (772).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (564).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (555).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (786).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (544).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (727).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (638).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (524).jpg
#   inflating: brain_tumor/Training/no_tumor/image (4).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (547).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (743).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (748).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (497).jpg
#   inflating: brain_tumor/Training/no_tumor/image (7).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (522).jpg
#   inflating: brain_tumor/Training/no_tumor/image(161).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (569).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (766).jpg
#   inflating: brain_tumor/Training/no_tumor/image(55).jpg
#   inflating: brain_tumor/Training/no_tumor/image (45).jpg
#   inflating: brain_tumor/Training/no_tumor/image(309).jpg
#   inflating: brain_tumor/Training/no_tumor/image(298).jpg
#   inflating: brain_tumor/Training/no_tumor/image(302).jpg
#   inflating: brain_tumor/Training/no_tumor/image(171).jpg
#   inflating: brain_tumor/Training/no_tumor/image(155).jpg
#   inflating: brain_tumor/Training/no_tumor/image(279).jpg
#   inflating: brain_tumor/Training/no_tumor/image(130).jpg
#   inflating: brain_tumor/Training/no_tumor/image(78).jpg
#   inflating: brain_tumor/Training/no_tumor/image(126).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (687).jpg
#   inflating: brain_tumor/Training/no_tumor/image (29).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (633).jpg
#   inflating: brain_tumor/Training/no_tumor/image(150).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (506).jpg
#   inflating: brain_tumor/Training/no_tumor/image(323).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (504).jpg
#   inflating: brain_tumor/Training/no_tumor/image(261).jpg
#   inflating: brain_tumor/Training/no_tumor/image(270).jpg
#   inflating: brain_tumor/Training/no_tumor/image(54).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (746).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (667).jpg
#   inflating: brain_tumor/Training/no_tumor/image(140).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (602).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (542).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (734).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (559).jpg
#   inflating: brain_tumor/Training/no_tumor/image(89).jpg
#   inflating: brain_tumor/Training/no_tumor/image(275).jpg
#   inflating: brain_tumor/Training/no_tumor/image(99).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (731).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (761).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (725).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (716).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (720).jpg
#   inflating: brain_tumor/Training/no_tumor/image(231).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (700).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (752).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (812).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (673).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (744).jpg
#   inflating: brain_tumor/Training/no_tumor/image(177).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (681).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (540).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (502).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (651).jpg
#   inflating: brain_tumor/Training/no_tumor/image(90).jpg
#   inflating: brain_tumor/Training/no_tumor/image(19).jpg
#   inflating: brain_tumor/Training/no_tumor/image(324).jpg
#   inflating: brain_tumor/Training/no_tumor/image (55).jpg
#   inflating: brain_tumor/Training/no_tumor/image(13).jpg
#   inflating: brain_tumor/Training/no_tumor/image(82).jpg
#   inflating: brain_tumor/Training/no_tumor/image(44).jpg
#   inflating: brain_tumor/Training/no_tumor/image(250).jpg
#   inflating: brain_tumor/Training/no_tumor/image (33).jpg
#   inflating: brain_tumor/Training/no_tumor/image(141).jpg
#   inflating: brain_tumor/Training/no_tumor/image(285).jpg
#   inflating: brain_tumor/Training/no_tumor/image(289).jpg
#   inflating: brain_tumor/Training/no_tumor/image(8).jpg
#   inflating: brain_tumor/Training/no_tumor/image(139).jpg
#   inflating: brain_tumor/Training/no_tumor/image(277).jpg
#   inflating: brain_tumor/Training/no_tumor/image(180).jpg
#   inflating: brain_tumor/Training/no_tumor/image(12).jpg
#   inflating: brain_tumor/Training/no_tumor/image(229).jpg
#   inflating: brain_tumor/Training/no_tumor/image(304).jpg
#   inflating: brain_tumor/Training/no_tumor/image(186).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (526).jpg
#   inflating: brain_tumor/Training/no_tumor/image(81).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (478).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (437).jpg
#   inflating: brain_tumor/Training/no_tumor/image(225).jpg
#   inflating: brain_tumor/Training/no_tumor/image(110).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (787).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (479).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (652).jpg
#   inflating: brain_tumor/Training/no_tumor/image(265).jpg
#   inflating: brain_tumor/Training/no_tumor/image(134).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (738).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (465).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (688).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (471).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (442).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (612).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (728).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (501).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (448).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (419).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (486).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (462).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (453).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (426).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (446).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (637).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (408).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (689).jpg
#   inflating: brain_tumor/Training/no_tumor/image(49).jpg
#   inflating: brain_tumor/Training/no_tumor/image(307).jpg
#   inflating: brain_tumor/Training/no_tumor/image (57).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (409).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (616).jpg
#   inflating: brain_tumor/Training/no_tumor/image(14).jpg
#   inflating: brain_tumor/Training/no_tumor/image (34).jpg
#   inflating: brain_tumor/Training/no_tumor/image(219).jpg
#   inflating: brain_tumor/Training/no_tumor/image(236).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (395).jpg
#   inflating: brain_tumor/Training/no_tumor/7.jpg
#   inflating: brain_tumor/Training/no_tumor/image (47).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (411).jpg
#   inflating: brain_tumor/Training/no_tumor/image (32).jpg
#   inflating: brain_tumor/Training/no_tumor/image(297).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (398).jpg
#   inflating: brain_tumor/Training/no_tumor/image(164).jpg
#   inflating: brain_tumor/Training/no_tumor/image(212).jpg
#   inflating: brain_tumor/Training/no_tumor/image(120).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (396).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (435).jpg
#   inflating: brain_tumor/Training/no_tumor/image(56).jpg
#   inflating: brain_tumor/Training/no_tumor/image (48).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (459).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (401).jpg
#   inflating: brain_tumor/Training/no_tumor/image (59).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (415).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (469).jpg
#   inflating: brain_tumor/Training/no_tumor/image(300).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (464).jpg
#   inflating: brain_tumor/Training/no_tumor/image(107).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (429).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (418).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (461).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (492).jpg
#   inflating: brain_tumor/Training/no_tumor/image(181).jpg
#   inflating: brain_tumor/Training/no_tumor/image (63).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (488).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (441).jpg
#   inflating: brain_tumor/Training/no_tumor/image(36).jpg
#   inflating: brain_tumor/Training/no_tumor/image(83).jpg
#   inflating: brain_tumor/Training/no_tumor/image(102).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (482).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (491).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (450).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (397).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (451).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (421).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (456).jpg
#   inflating: brain_tumor/Training/no_tumor/image(238).jpg
#   inflating: brain_tumor/Training/no_tumor/image(239).jpg
#   inflating: brain_tumor/Training/no_tumor/image(104).jpg
#   inflating: brain_tumor/Training/no_tumor/image(286).jpg
#   inflating: brain_tumor/Training/no_tumor/image(11).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (487).jpg
#   inflating: brain_tumor/Training/no_tumor/image(273).jpg
#   inflating: brain_tumor/Training/no_tumor/image(305).jpg
#   inflating: brain_tumor/Training/no_tumor/image(39).jpg
#   inflating: brain_tumor/Training/no_tumor/image (27).jpg
#   inflating: brain_tumor/Training/no_tumor/image(121).jpg
#   inflating: brain_tumor/Training/no_tumor/image(288).jpg
#   inflating: brain_tumor/Training/no_tumor/image(85).jpg
#   inflating: brain_tumor/Training/no_tumor/image(118).jpg
#   inflating: brain_tumor/Training/no_tumor/image(182).jpg
#   inflating: brain_tumor/Training/no_tumor/image(162).jpg
#   inflating: brain_tumor/Training/no_tumor/image(106).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (452).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (463).jpg
#   inflating: brain_tumor/Training/no_tumor/image (12).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (458).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (431).jpg
#   inflating: brain_tumor/Training/no_tumor/image(95).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (423).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (394).jpg
#   inflating: brain_tumor/Training/no_tumor/image(124).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (460).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (438).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (402).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (425).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (485).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (413).jpg
#   inflating: brain_tumor/Training/no_tumor/image(111).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (428).jpg
#   inflating: brain_tumor/Training/no_tumor/image(196).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (455).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (424).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (417).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (403).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (436).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (477).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (474).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (447).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (483).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (400).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (439).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (404).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (454).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (449).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (472).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (443).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (414).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (405).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (467).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (493).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (412).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (406).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (422).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (468).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (473).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (445).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (489).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (476).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (490).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (407).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (470).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (393).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (433).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (444).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (457).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (410).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (420).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (481).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (432).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (466).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (484).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (475).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (440).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (480).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (399).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (427).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (434).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (416).jpg
#   inflating: brain_tumor/Training/pituitary_tumor/p (430).jpg

# %% [markdown]
# We have stored the images in a structured folder, and below we create the data paths to load images from those folders. This is required so that we can extract images in an auto-labelled fashion using Keras **flow_from_directory**.

# %%
# Parent directory where images are stored in drive
parent_dir = 'brain_tumor'

# Path to the training and testing datasets within the parent directory
train_dir = os.path.join(parent_dir, 'Training')
validation_dir = os.path.join(parent_dir, 'Testing')

# Directory with our training pictures
train_pituitary_dir = os.path.join(train_dir, 'pituitary_tumor')
train_no_dir = os.path.join(train_dir, 'no_tumor')

# Directory with our testing pictures
validation_pituitary_dir = os.path.join(validation_dir, 'pituitary_tumor')
validation_no_dir = os.path.join(validation_dir, 'no_tumor')

# %% [markdown]
# ## **Visualizing a few images**

# %% [markdown]
# Before we move ahead and perform data augmentation, let's randomly check out some of the images and see what they look like:

# %%
train_pituitary_file_names = os.listdir(train_pituitary_dir)
train_no_file_names = os.listdir(train_no_dir)

fig = plt.figure(figsize=(16, 8))
fig.set_size_inches(16, 16)

pituitary_img_paths = [os.path.join(train_pituitary_dir, file_name) for file_name in train_pituitary_file_names[:16]]
no_img_paths = [os.path.join(train_no_dir, file_name) for file_name in train_no_file_names[:16]]

for i, img_path in enumerate(pituitary_img_paths + no_img_paths):
    ax = plt.subplot(8, 4, i + 1)
    ax.axis('Off')

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %% [markdown]
# As we can see, the images are quite different in size from each other.
#
# This represents a problem, as most CNN architectures, including the pre-built model architectures that we will use for Transfer Learning, **expect all the images to have the same size.**
#
# So we need to crop these images from the center to make sure they all have the same size. We can do this automatically while performing Data Augmentation, as shown below.

# %% [markdown]
# ## **Data Augmentation**
#
# In most real-life case studies, it is generally difficult to collect lots of images and then train CNNs. In that case, one idea we can take advantage of is Data Augmentation. CNNs have the property of **translational invariance**, i.e., they can recognize an object as an object, even when its appearance varies translationally in some way. Taking this property into consideration, we can augment the images using the following techniques:

# %% [markdown]
# **1. Horizontal Flip** (should be set to True/False) <br>
# **2. Vertical Flip** (should be set to True/False) <br>
# **3. Height Shift** (should be between 0 and 1) <br>
# **4. Width Shift** (should be between 0 and 1) <br>
# **5. Rotation** (should be between 0 and 180) <br>
# **6. Shear** (should be between 0 and 1) <br>
# **7. Zoom** (should be between 0 and 1) etc. <br>
#
# Remember ***not to use data augmentation in the validation/test data set***.

# %% [markdown]
# Also, as mentioned above, we need to have images of the same size. So below,we resize the images by using the parameter **target_size**. Here we are resizing it to **224 x 224**, as we will be using the **VGG16** model for Transfer Learning, which takes image inputs as **224 x 224**.
#
# As this is a binary classification problem, we will need class labels. This is directly handled by the **flow_from_directory** function. It will take the images from the folder inside our specified directory, and the images from one folder will belong to same class.
#
# As the train directory has 2 folders pituitary_tumor and no_tumor, it will read the directory and each folder will be considered a separate class. We specify **class_model = 'binary'** as this is a binary classification problem.
#
# As the folders inside the directory will be read in an alphabetical order, the no_tumor folder will be given a label 0, and pituitary_tumor will be label 1.

# %%
# All images to be rescaled by 1/255.
train_datagen = ImageDataGenerator(rescale=1. / 255.0,
                              horizontal_flip = True,
                              vertical_flip = False,
                              height_shift_range= 0.1,
                              width_shift_range=0.1,
                              rotation_range=20,
                              shear_range = 0.1,
                              zoom_range=0.1)
test_datagen  = ImageDataGenerator(rescale = 1.0/255.)

# Flowing training images in batches of 20 using train_datagen generator
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=20,
                                                    class_mode='binary',
                                                    target_size=(224, 224))

# Flowing testing images in batches of 20 using test_datagen generator
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                         batch_size=20,
                                                         class_mode  = 'binary',
                                                         target_size = (224, 224))
# Out:
# Found 830 images belonging to 2 classes.
# Found 170 images belonging to 2 classes.

# %% [markdown]
# Let's look at some examples of our augmented training data.
#
# This is helpful for understanding the extent to which data is being manipulated prior to training, and can be compared with how the raw data looks prior to data augmentation.

# %%
images, labels = next(train_generator)
fig, axes = plt.subplots(4, 4, figsize = (16, 8))
fig.set_size_inches(16, 16)
for (image, label, ax) in zip(images, labels, axes.flatten()):
    ax.imshow(image)
    if label == 1:
        ax.set_title('pituitary tumor')
    else:
        ax.set_title('no tumor')
    ax.axis('off')

# %% [markdown]
# ## **CNN Model Building**

# %% [markdown]
# Once the data is augmented and cropped to have the same size, we are now ready to build a first baseline CNN model to classify no_tumor vs pituitary_tumor.
#
# When building our custom model, we have used Batch Normalization and Dropout layers as regularization techniques to prevent overfitting.

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(64, (3,3), activation='relu', input_shape=(224, 224, 3), padding = 'same'))
cnn_model.add(MaxPooling2D(2,2))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv2D(32, (3,3), activation='relu', padding = 'same'))
cnn_model.add(MaxPooling2D(2,2))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv2D(32, (3,3), activation='relu', padding = 'same'))
cnn_model.add(MaxPooling2D(2,2))
cnn_model.add(Conv2D(16, (3,3), activation='relu', padding = 'same'))
cnn_model.add(Flatten())
cnn_model.add(Dense(64, activation='relu'))
cnn_model.add(Dropout(0.25))
cnn_model.add(Dense(32, activation='relu'))
cnn_model.add(Dropout(0.25))
cnn_model.add(Dense(32, activation='relu'))
cnn_model.add(Dense(1, activation='sigmoid'))

# %%
cnn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics = ['accuracy'])
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  batch_normalization (Batch  (None, 112, 112, 64)      256
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 56, 56, 32)        128
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 16)        4624
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 64)                802880
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 840561 (3.21 MB)
# Trainable params: 840369 (3.21 MB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
# Pulling a single large batch of random testing data for testing after each epoch
testX, testY = validation_generator.next()

# %%
model_history = cnn_model.fit(train_generator,
                              validation_data=(testX, testY),
                              epochs=10)
# Out:
# Epoch 1/10
# 42/42 [==============================] - 18s 216ms/step - loss: 0.5402 - accuracy: 0.7518 - val_loss: 0.7311 - val_accuracy: 0.5000
# Epoch 2/10
# 42/42 [==============================] - 9s 214ms/step - loss: 0.3846 - accuracy: 0.8458 - val_loss: 1.3172 - val_accuracy: 0.5000
# Epoch 3/10
# 42/42 [==============================] - 9s 212ms/step - loss: 0.3029 - accuracy: 0.8928 - val_loss: 0.9464 - val_accuracy: 0.4500
# Epoch 4/10
# 42/42 [==============================] - 9s 212ms/step - loss: 0.3690 - accuracy: 0.8627 - val_loss: 0.6951 - val_accuracy: 0.4500
# Epoch 5/10
# 42/42 [==============================] - 9s 219ms/step - loss: 0.2840 - accuracy: 0.8867 - val_loss: 1.9740 - val_accuracy: 0.4500
# Epoch 6/10
# 42/42 [==============================] - 9s 213ms/step - loss: 0.2563 - accuracy: 0.8940 - val_loss: 0.6788 - val_accuracy: 0.5000
# Epoch 7/10
# 42/42 [==============================] - 9s 209ms/step - loss: 0.2108 - accuracy: 0.9253 - val_loss: 0.5584 - val_accuracy: 0.6500
# Epoch 8/10
# 42/42 [==============================] - 9s 213ms/step - loss: 0.1556 - accuracy: 0.9398 - val_loss: 0.4070 - val_accuracy: 0.8500
# Epoch 9/10
# 42/42 [==============================] - 9s 211ms/step - loss: 0.3353 - accuracy: 0.8843 - val_loss: 0.7781 - val_accuracy: 0.7000
# Epoch 10/10
# 42/42 [==============================] - 9s 213ms/step - loss: 0.1877 - accuracy: 0.9289 - val_loss: 0.6233 - val_accuracy: 0.7500

# %%
# Evaluating on the Test dataset
cnn_model.evaluate(validation_generator)
# Out:
# 9/9 [==============================] - 1s 44ms/step - loss: 0.5417 - accuracy: 0.8176
# [0.5416545867919922, 0.8176470398902893]

# %% [markdown]
# ### **Findings**
#
# - Our model had 840,369 trainable parameters.
# - After running 10 epochs, we were able to achieve a training accuracy of ~95% and a testing accuracy of ~72%.
# - Even after using Data Augmentation, Batch Normalization and the Dropout Layers, the model seems to have highly overfit on the training dataset and is performing somewhat poorly.

# %% [markdown]
# ## **Model Building using Transfer Learning: VGG 16**

# %% [markdown]
# - Now, let's try again, but this time, using the idea of **Transfer Learning**. We will be loading a pre-built architecture - **VGG16**, which was trained on the ImageNet dataset and finished runner-up in the ImageNet competition in 2014. Below is a schematic of the VGG16 model.
#
# - For training VGG16, we will directly use the convolutional and pooling layers and freeze their weights i.e. no training will be done on them. We will remove the already-present fully-connected layers and add our own fully-connected layers for this binary classification task.

# %% [markdown]
# ![vgg16](https://upload.wikimedia.org/wikipedia/commons/2/24/VGG16.png)

# %%
# Summary of the whole model
model = VGG16(weights='imagenet')
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 21s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138357544 (527.79 MB)
# Trainable params: 138357544 (527.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Getting only the conv layers for transfer learning.
transfer_layer = model.get_layer('block5_pool')

# %%
vgg_model = Model(inputs=model.input, outputs=transfer_layer.output)

# %%
vgg_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - To remove the fully-connected layers of the imported pre-trained model, while calling it from Keras we can also specify an additonal keyword argument that is **include_top**.
#
# - **If we specify include_top = False, then the model will be imported without the fully-connected layers.** Here we won't have to do the above steps of getting the last convolutional layer and creating a separate model.
#
# - If we are specifying include_top = False, we will also have to specify our input image shape.
#
# - Keras has this keyword argument as generally while importing a pre-trained CNN model, we don't require the fully-connected layers and we train our own fully-connected layers for our task.

# %%
vgg_model = VGG16(weights='imagenet', include_top = False, input_shape = (224,224,3))
vgg_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Making all the layers of the VGG model non-trainable. i.e. freezing them
for layer in vgg_model.layers:
    layer.trainable = False

# %%
for layer in vgg_model.layers:
    print(layer.name, layer.trainable)
# Out:
# input_2 False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 False
# block2_pool False
# block3_conv1 False
# block3_conv2 False
# block3_conv3 False
# block3_pool False
# block4_conv1 False
# block4_conv2 False
# block4_conv3 False
# block4_pool False
# block5_conv1 False
# block5_conv2 False
# block5_conv3 False
# block5_pool False

# %%
new_model = Sequential()

# Adding the convolutional part of the VGG16 model from above
new_model.add(vgg_model)

# Flattening the output of the VGG16 model because it is from a convolutional layer
new_model.add(Flatten())

# Adding a dense output layer
new_model.add(Dense(32, activation='relu'))
new_model.add(Dense(32, activation='relu'))
new_model.add(Dense(1, activation='sigmoid'))

# %%
new_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 32)                802848
#
#  dense_5 (Dense)             (None, 32)                1056
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 15518625 (59.20 MB)
# Trainable params: 803937 (3.07 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
## Fitting the VGG model
new_model_history = new_model.fit(train_generator,
                                  validation_data=(testX, testY),
                                  epochs=10)
# Out:
# Epoch 1/10
# 42/42 [==============================] - 10s 237ms/step - loss: 0.0330 - accuracy: 0.9928 - val_loss: 0.4943 - val_accuracy: 0.8500
# Epoch 2/10
# 42/42 [==============================] - 9s 221ms/step - loss: 0.0354 - accuracy: 0.9928 - val_loss: 0.6050 - val_accuracy: 0.8000
# Epoch 3/10
# 42/42 [==============================] - 9s 215ms/step - loss: 0.0365 - accuracy: 0.9867 - val_loss: 0.3226 - val_accuracy: 0.8500
# Epoch 4/10
# 42/42 [==============================] - 9s 218ms/step - loss: 0.0301 - accuracy: 0.9880 - val_loss: 0.0789 - val_accuracy: 1.0000
# Epoch 5/10
# 42/42 [==============================] - 9s 220ms/step - loss: 0.0379 - accuracy: 0.9867 - val_loss: 0.7630 - val_accuracy: 0.8000
# Epoch 6/10
# 42/42 [==============================] - 9s 219ms/step - loss: 0.0246 - accuracy: 0.9928 - val_loss: 0.7035 - val_accuracy: 0.7500
# Epoch 7/10
# 42/42 [==============================] - 10s 226ms/step - loss: 0.0157 - accuracy: 0.9940 - val_loss: 0.4086 - val_accuracy: 0.8500
# Epoch 8/10
# 42/42 [==============================] - 9s 218ms/step - loss: 0.0134 - accuracy: 0.9928 - val_loss: 0.0929 - val_accuracy: 0.9500
# Epoch 9/10
# 42/42 [==============================] - 9s 221ms/step - loss: 0.0438 - accuracy: 0.9843 - val_loss: 0.4405 - val_accuracy: 0.9000
# Epoch 10/10
# 42/42 [==============================] - 9s 218ms/step - loss: 0.0204 - accuracy: 0.9916 - val_loss: 0.0908 - val_accuracy: 0.9500

# %%
# Evaluating on the Test set
new_model.evaluate(validation_generator)
# Out:
# 9/9 [==============================] - 1s 89ms/step - loss: 0.0968 - accuracy: 0.9471
# [0.09681539982557297, 0.9470587968826294]

# %%
# Function to plot loss, val_loss,
def plot_history(history):
    N = len(history.history["accuracy"])
    plt.figure()
    plt.plot(np.arange(0, N), history.history["accuracy"], label="train_accuracy")
    plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_accuracy")
    plt.title("Training accuracy Dataset")
    plt.xlabel("Epoch #")
    plt.ylabel("accuracy")
    plt.legend(loc="upper right")

# %%
# Plotting the loss vs epoch curve for the basic CNN model without Transfer Learning
plot_history(model_history)

# %%
# Plotting the loss vs epoch curve for the Transfer Learning model
plot_history(new_model_history)

# %% [markdown]
# ### Findings
#
# - Our model has 803,937 Trainable parameters.
# - After running 5 epochs we were able to achieve a training accuracy of ~98% and a validation accuracy of ~ 91%.

# %% [markdown]
# ## **Conclusions**
#
# - The difference in both models is evident. Both models had nearly the same number of trainable parameters. However even after training the custom CNN model for 10 epochs, it could not attain accuracies as high as we achieved with Transfer Learning.
#
# - The Transfer Learning model has converged faster than the custom CNN model in only 5 epochs.
#
# - That's a good level of improvement just by directly using a pre-trained architecture such as VGG16.
#
# - This model can, in fact, further be tuned to achieve the accuracies required for practical applicability in the medical domain.
